# %%
import datetime
from os import path
import math
import git

import random
import numpy as np
import torch
from torch.utils.data import DataLoader

from model.trainer import XMemTrainer
from dataset.vos_dataset import VOSDataset

from util.logger import TensorboardLogger
from util.configuration import Configuration
from util.load_subset import load_sub_davis, load_sub_yv

# %%
yv_root = "../YouTube/train"
train_dataset = VOSDataset(path.join(yv_root, 'JPEGImages'), 
                       path.join(yv_root, 'Annotations'), 
                       2, 
                       is_bl=False)
# Out:
# .DS_Store not accepted
# 2 out of 3 videos accepted in ../YouTube/train/JPEGImages.

# %%
train_loader = DataLoader(train_dataset, 2)

# %%
for data in train_loader:
    print(data)
# Out:
# {'rgb': tensor([[[[[-0.0116, -0.0116, -0.0116,  ..., -0.0116, -0.0116, -0.0116],
#            [-0.0116, -0.0116, -0.0116,  ..., -0.0116, -0.0116, -0.0116],
#            [-0.0116, -0.0116, -0.0116,  ..., -0.0116, -0.0116, -0.0116],
#            ...,
#            [-0.0116, -0.0116, -0.0116,  ..., -0.0116, -0.0116, -0.0116],
#            [-0.0116, -0.0116, -0.0116,  ..., -0.0116, -0.0116, -0.0116],
#            [-0.0116, -0.0116, -0.0116,  ..., -0.0116, -0.0116, -0.0116]],
#
#           [[-0.0224, -0.0224, -0.0224,  ..., -0.0224, -0.0224, -0.0224],
#            [-0.0224, -0.0224, -0.0224,  ..., -0.0224, -0.0224, -0.0224],
#            [-0.0224, -0.0224, -0.0224,  ..., -0.0224, -0.0224, -0.0224],
#            ...,
#            [-0.0224, -0.0224, -0.0224,  ..., -0.0224, -0.0224, -0.0224],
#            [-0.0224, -0.0224, -0.0224,  ..., -0.0224, -0.0224, -0.0224],
#            [-0.0224, -0.0224, -0.0224,  ..., -0.0224, -0.0224, -0.0224]],
#
# ...
